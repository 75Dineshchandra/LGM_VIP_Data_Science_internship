# %% [markdown]
# <a href="https://colab.research.google.com/github/75Dineshchandra/letsgrowmore_Data_Science_internship/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
#@ Dinesh Chandra Gaddam
### dineshsunnygaddam2002@gmail.com

# %%
## Task-4 : Image to Pencil Sketch with Python

# %%
### Now the thing to do is to read the image:

# %%
image=cv2.imread("solo_levelling.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=496x670 at 0x7F4018165250>

# %%
### Now after reading the image, we will create a new image by converting the original image to greyscale:

# %%
img=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=496x670 at 0x7F40180FDD90>

# %%
### Now the next step is to invert the new grayscale image:

# %%
negative=cv2.bitwise_not(img)
cv2_imshow(negative)
# Out:
# <PIL.Image.Image image mode=L size=496x670 at 0x7F40180E3490>

# %%
### Now the next step in the process is to blur the image by using the Gaussian Function in OpenCV:

# %%
blurred=cv2.GaussianBlur(negative, (25,25),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=496x670 at 0x7F4018102550>

# %%
### Then the final step is to invert the blurred image, then we can easily convert the image into a pencil sketch:

# %%
inv=cv2.bitwise_not(blurred)
cv2_imshow(inv)
# Out:
# <PIL.Image.Image image mode=L size=496x670 at 0x7F40180DC990>

# %%
 pencil_sketch=cv2.divide(img,inv, scale=256.0)
cv2.imwrite('sketch.png', pencil_sketch)
cv2_imshow( pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=496x670 at 0x7F40180DCE50>

# %%
### let's put them together and compare

# %%
cv2_imshow(image )
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=496x670 at 0x7F40180F2810>
# <PIL.Image.Image image mode=L size=496x670 at 0x7F401689F310>
